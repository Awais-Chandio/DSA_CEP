# %% [markdown]
# # Data Loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.metrics import confusion_matrix, classification_report


iris = load_iris()

print(dir(iris))
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'frame', 'target', 'target_names']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
df['Target'] =iris.target
df['Flower name'] = df.Target.apply(lambda x: iris.target_names[x])

df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target Flower name
# ...

# %%
df[df.Target == 0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target Flower name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df[df.Target == 1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     Target Flower name
# 50       1  versicolor
# 51       1  versicolor
# 52       1  versicolor
# 53       1  versicolor
# 54       1  versicolor

# %%
df[df.Target == 2
  
  ].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      Target Flower name
# 100       2   virginica
# 101       2   virginica
# 102       2   virginica
# 103       2   virginica
# 104       2   virginica

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
df0 = df[df.Target ==0]
df1 = df[df.Target ==1]
df2 = df[df.Target ==2]

print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# #  Data Visualization

# %%
# Pairplot for pairwise relationships between features colored by target class
sns.pairplot(df, hue='Target', palette='Set1')
plt.title('Pairplot of Iris Features')
plt.show()

# %%
# Box plot for comparing feature distributions by target class
plt.figure(figsize=(10, 6))
sns.boxplot(x='Target', y='sepal length (cm)', data=df)
plt.title('Box Plot of Sepal Length by Target Class')
plt.show()

# %%
# Violin plot for comparing feature distributions by target class
plt.figure(figsize=(10, 6))
sns.violinplot(x='Target', y='sepal width (cm)', data=df)
plt.title('Violin Plot of Sepal Width by Target Class')
plt.show()

# %%
# Histogram for petal length
plt.figure(figsize=(8, 6))
sns.histplot(df['petal length (cm)'], bins=20, kde=True)
plt.title('Histogram of Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation matrix heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Scatter plot of sepal length vs sepal width, colored by target class
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue='Target', data=df, palette='Set1')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
# Scatter plot of petal length vs petal width, colored by target class
plt.figure(figsize=(8, 6))
sns.scatterplot(x='petal length (cm)', y='petal width (cm)', hue='Target', data=df, palette='Set1')
plt.title('Scatter Plot of Petal Length vs Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# %%
# Countplot for target class distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Target', data=df, palette='Set1')
plt.title('Countplot of Target Classes')
plt.xlabel('Target Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Splitting Data into Training and Testing Splits

# %%
# Splititng data into input features and class labels
X = df.drop(['Target', 'Flower name'], axis='columns')
Y = df.Target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# # Building a Machine Learning Model

# %%
from sklearn.svm import SVC
svm_model = SVC()

svm_model.fit(x_train, y_train)
y_pred= svm_model.predict(x_test)

# %% [markdown]
# # Model Evaluation

# %%
#Accuracy score (for training data)
from sklearn.metrics import accuracy_score

svm_model.predict(x_train)
y_pred = svm_model.predict(x_test)
print('Accuracy on training data is :',svm_model.score(x_train, y_train))
# Calculate accuracy
svm_accuracy = accuracy_score(y_test, y_pred)
print("Accuracy on testing data is  : ",log_accuracy)
# Out:
# Accuracy on training data is : 0.9833333333333333
# Accuracy on testing data is  :  0.9333333333333333

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Classification Report
class_report = classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1', 'Class 2'])
print('Classification Report:')
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        13
#      Class 1       0.90      1.00      0.95         9
#      Class 2       1.00      0.88      0.93         8
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

log_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Accuracy score (for training data)
log_model.predict(x_train)
y_pred = log_model.predict(x_test)
print('Accuracy on training data is :',log_model.score(x_train, y_train))
# Calculate accuracy
log_accuracy = accuracy_score(y_test, y_pred)
print("Accuracy on testing data is  : ",log_accuracy)
# Out:
# Accuracy on training data is : 0.975
# Accuracy on testing data is  :  0.9333333333333333

# %% [markdown]
# # Accuracy comparison between Two Models

# %%
# Accuracy scores for training and testing data
train_accuracies = [svm_model.score(x_train, y_train), log_model.score(x_train, y_train)]
test_accuracies = [svm_accuracy, log_accuracy]

# Classifiers
classifiers = ['SVM', 'Logistic Regression']
bar_width = 0.35
index = np.arange(len(classifiers))

# Create subplots
fig, ax = plt.subplots(figsize=(10, 6))

# Plot training accuracies
train_bars = ax.bar(index, train_accuracies, bar_width, label='Training Accuracy', color='skyblue', alpha=0.7)

# Plot testing accuracies
test_bars = ax.bar(index + bar_width, test_accuracies, bar_width, label='Testing Accuracy', color='lightgreen', alpha=0.7)

# Add labels, title, and legend
ax.set_xlabel('Classifier')
ax.set_ylabel('Accuracy')
ax.set_title('Classifier Accuracy Comparison (Training vs. Testing)')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(classifiers)
ax.legend()

# Annotate the bars with accuracy values
for i, v in enumerate(train_accuracies):
    ax.text(i, v + 0.01, f'{v:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='blue')

for i, v in enumerate(test_accuracies):
    ax.text(i + bar_width, v + 0.01, f'{v:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold', color='green')

# Add error bars to show the variation
ax.errorbar(index, train_accuracies, yerr=0.02, fmt='o', color='blue', capsize=5, label='Train ± Std Dev')
ax.errorbar(index + bar_width, test_accuracies, yerr=0.02, fmt='o', color='green', capsize=5, label='Test ± Std Dev')

# Add a grid for reference
ax.grid(axis='y', linestyle='--', alpha=0.6)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Making Predictions from the Trained Model

# %%
dummy_data = np.array([[5.1, 3.5, 1.4, 0.2],  # Sample 1
                       [6.3, 3.3, 4.7, 1.6],  # Sample 2
                       [7.0, 3.2, 4.5, 1.5]])  # Sample 3

# SVM Model
svm_predictions = svm_model.predict(dummy_data)

# Logistic Regression model
logistic_predictions = log_model.predict(dummy_data)


class_mapping = {0: 'Setosa', 1: 'Virginica', 2: 'Versicolor'}

# Convert numerical predictions to flower names
svm_predictions_names = [class_mapping[label] for label in svm_predictions]
logistic_predictions_names = [class_mapping[label] for label in logistic_predictions]

print("SVM Predictions:")
print(svm_predictions_names)

print("\nLogistic Regression Predictions:")
print(logistic_predictions_names)
# Out:
# SVM Predictions:
# ['Setosa', 'Virginica', 'Virginica']
#
# Logistic Regression Predictions:
# ['Setosa', 'Virginica', 'Virginica']
